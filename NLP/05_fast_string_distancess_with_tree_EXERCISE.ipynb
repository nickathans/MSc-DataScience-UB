# %% [markdown]
# # String distances

# %%
import nltk
import numpy as np
import pandas as pd
import editdistance

# %%
words = nltk.corpus.words.words()

# %%
pd.DataFrame(words).to_csv("words_nltk.csv")

# %% [markdown]
# # BK tree
#
# ## How to create a BK-tree
#
# - take any word from your set and use it in as your root node. Add word to the tree based on their distance to the root.
#
# - A subtree within the tree will be a node and all its downstream nodes and weights. We can represent this as a pair storing:
#     - `(node: str, subtree_of_node: Dict[int, Tuple(str, ... )])`.

# %% [markdown]
# ### Example
#
# - Let us consider we started a tree with the word set [**book**, **books**, **cake**] then my tree would look like this if I started by making the word **book**:
#
# ```
#        1
# book ----- books
#     |
#     | 4
#     ----cake
# ```
#
# We can represent this tree in memory as a pair
# `(Node, Subtree below Node)`. That is:
#
# ```
# {('book', {1: ('books', {}), 4: ('cake', {})})}
# ```
#
#
# - Add **boo**. Now we want to add the word **boo** which is at distace 1 from book. Notice though that there is already **book** at distance 1. The BK tree has to respect that every node have all children with different distances. If there is a colission (like we have now) then the new word must become a children of the node with which there was the colition. In this case, a children of **book**. The new weight from **books** to **boo** has to be `edit_dis(books,boo)=2`.
#
# ```
#        1           2
# book ----- books ----- boo
#     |
#     | 4
#     ----cake
# ```
#
# #### Adding [**cape**,**cart**,**boon**,**cook**].
#
# - Add **cape**. Notice `edit_dis(books,cape)=4` but **cake** is altready at distance 4. Therefore **cape** needs to be a child of **cake** with a weighted edge of weight `edit_dis(cake,cape)=1`.
# ```
#        1           2
# book ----- books ----- boo
#     |
#     | 4        1
#     ----cake ----- cape
# ```
#
# - Add **cart**. Notice `edit_dis(books,cart)=4`. Therefore **cart** needs to be a children of **cake** (or any subchildren of cake). Since `edit_dis(cake,cart)=2` then :
# ```
#        1           2
# book ----- books ----- boo
#     |
#     | 4        1
#     ----cake ----- cape
#            |
#            | 2
#            ----- cart
# ```
#
# - Add **boon**. Notice  `edit_dis(book,boon)=1`. Therefore **boon** has to be a descendant of **books** (because books is a son of book with weight 1). Notice `edit_dis(books,boon)=2` but there is already node **boo** at distance 2. Therefore **boon** needs to be a descendant of **boo**. Notice `edit_dis(boo,boon)=1`.
#
# ```
#        1           2         1
# book ----- books ----- boo ----- boon
#     |
#     | 4        1
#     ----cake ----- cape
#            |
#            | 2
#            ----- cart
# ```
#
# - Add **cook**.  Notice  `edit_dis(book,cook)=1` but book contains a descendant at distance 1, books, so cook has to be a dascendant of books.  Notice  `edit_dis(books,cook)=2` but books has a descendant at distance 2, **boo**, so cook has to be a descendant of boo.   Notice  `edit_dis(boo,cook)=2` and boo has no other descendant at distance 2. Therefore we can add cook as descendant of boo with weight 2.
#
# ```
#        1           2         1
# book ----- books ----- boo ----- boon
#     |                    |
#     |                    |  2
#     |                    ------ cook
#     | 4        1
#     ----cake ----- cape
#            |
#            | 2
#            ----- cart
# ```

# %% [markdown]
# ## How to code a BK tree
#
# Now we would like to know how do we construct a bk-tree in python and store it. A natural way to store a tree is using many tuples concatenated. Since a tree
#
#
#
#
# ##### Exercise: fill in the BKTree class to create a tree

# %%
edit_distance = editdistance.eval

# %%
words[0:10]
# Out:
# ['A',
#  'a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'Aani',
#  'aardvark',
#  'aardwolf',
#  'Aaron']

# %%
class BKTree:
    def __init__(self, distfn, words):
        self.distfn = distfn

        it = iter(words)
        root = next(it)
        self.tree = (root, {})

        for w in it:
            self._add_word(self.tree, w)

    def _add_word(self, parent, word):
        pword, children = parent   # ('pepe', {1:[], 2:[]})
        d = self.distfn(word, pword)
        
        # TODO BEGIN ------------------------------------------
        # call _add_word recursively to keep adding words

        # TODO END --------------------------------------------

# %%
t = BKTree(edit_distance, ['book'])
t.tree
# Out:
# ('book', {})

# %%
t = BKTree(edit_distance, ['book', 'books'])
t.tree
# Out:
# ('book', {1: ('books', {})})

# %%
t = BKTree(edit_distance, ['book', 'books','cake'])
t.tree
# Out:
# ('book', {1: ('books', {}), 4: ('cake', {})})

# %%
words_simple = ['book', 'books', 'cake', 'boo'] 
t = BKTree(edit_distance, words_simple)
t.tree
# Out:
# ('book', {1: ('books', {2: ('boo', {})}), 4: ('cake', {})})

# %%
words_simple = ['book', 'books', 'cake', 'boo', 'cape', 'cart', 'boon', 'cook'] 
t = BKTree(edit_distance, words_simple)
t.tree
# Out:
# ('book',
#  {1: ('books', {2: ('boo', {1: ('boon', {}), 2: ('cook', {})})}),
#   4: ('cake', {1: ('cape', {}), 2: ('cart', {})})})

# %% [markdown]
# ### Building a BK-Tree with many words
#
# Let us see the cost of constructing the tree for `words` which has 23k strings

# %%
# %%time
t = BKTree(edit_distance, [w.lower() for w in words])
# Out:
# CPU times: user 2.87 s, sys: 216 ms, total: 3.08 s
# Wall time: 3.1 s

# %%
len(t.tree), len(t.tree[1]), type(t.tree[1])
# Out:
# (2, 24, dict)

# %%
t.tree[1].keys()
# Out:
# dict_keys([0, 1, 2, 4, 3, 7, 6, 8, 5, 10, 9, 11, 13, 15, 14, 19, 18, 16, 12, 17, 20, 21, 22, 23])

# %%
t.tree[1][12]
# Out:
# ('abdominoscope',
#  {1: ('abdominoscopy', {}),
#   9: ('abiogenetical',
#    {11: ('academization',
#      {9: ('acetopiperone',
#        {11: ('asperifolious',
#          {9: ('epidemiology', {}),
#           10: ('indefinitude', {7: ('sidelingwise', {})})}),
#         10: ('autocorrosion',
#          {9: ('chemiotropic', {}), 11: ('pronominalize', {})}),
#         9: ('autodiffusion', {})}),
#       10: ('actinomycosis',
#        {10: ('ambrosiaceous',
#          {11: ('apheliotropic', {}),
#           6: ('arundinaceous', {}),
#           7: ('chromiferous', {}),
#           8: ('proditorious', {})}),
#         11: ('amidothiazole',
#          {11: ('bromeliaceous', {11: ('rodomontadist', {})})}),
#         7: ('arteriostosis', {}),
#         12: ('asperifoliate',
#          {12: ('benziminazole', {}),
#           10: ('cannabinaceae', {11: ('hydrosilicon', {})}),
#           8: ('casuarinaceae', {}),
#           9: ('irremissible', {9: ('redemonstrate', {})})}),
#         9: ('cognoscitive', {})}),
#       11: ('adamantoblast',
#        {9: ('addressograph', {}),
#         10: ('aerolithology',
#          {10: ('aluminothermy', {11: ('thermantidote', {})}),
#           8: ('aphilanthropy', {11: ('criminologic', {})}),
#           11: ('audaciousness',
#            {10: ('cranioscopist', {}), 11: ('macroglossate', {})}),
#           12: ('unomniscient', {})}),
#         12: ('affenpinscher',
#          {11: ('arboriculture',
#            {10: ('associateship', {}),
#             12: ('delitescence', {13: ('macroprosopia', {})}),
#             11: ('laughingstock', {11: ('peridiniaceae', {})}),
#             9: ('noninductive', {})}),
#           13: ('chromotropic',
#            {9: ('incommodious',
#              {10: ('promiseproof', {}), 1: ('uncommodious', {})})}),
#           12: ('cynomoriaceae',
#            {11: ('encomiologic',
#              {10: ('homoiousious', {8: ('sudoriferous', {})})}),
#             9: ('entomologize', {}),
#             12: ('fibromyotomy', {}),
#             10: ('iodochloride', {})}),
#           10: ('shoeingsmith', {})}),
#         11: ('albuminimeter',
#          {2: ('albuminimetry', {}),
#           11: ('androdynamous',
#            {11: ('apocinchonine', {}),
#             9: ('autodiagnosis', {}),
#             12: ('bromoprotein', {}),
#             10: ('endomesoderm', {}),
#             13: ('mosquitocide', {})}),
#           9: ('appropinquate',
#            {10: ('becomingness', {}), 12: ('reminiscency', {})}),
#           10: ('asthenosphere',
#            {11: ('birminghamize', {10: ('oxyquinoline', {})}),
#             12: ('holomastigote', {11: ('pneumonotomy', {})}),
#             10: ('isoquinoline', {})}),
#           12: ('autopoisonous', {}),
#           8: ('bloomingness', {}),
#           13: ('endoproctous', {9: ('oidiomycosis', {})})}),
#         13: ('clinopinacoid',
#          {11: ('properispome', {}), 12: ('uncompulsive', {})})}),
#       12: ('adularescence',
#        {11: ('archigonocyte',
#          {10: ('atrociousness',
#            {11: ('hydrosilicate',
#              {13: ('jestingstock', {}),
#               11: ('laryngoscopic',
#                {13: ('recompensable', {2: ('uncompensable', {})})})}),
#             12: ('subcompensate', {})}),
#           11: ('benzinduline', {11: ('iodomercurate', {})}),
#           9: ('decomponible',
#            {11: ('mockingstock', {}), 8: ('semimolecule', {})}),
#           12: ('embryoscopic', {5: ('kinetoscopic', {})}),
#           13: ('pelomedusoid', {}),
#           8: ('semiconcrete', {}),
#           7: ('zoocoenocyte', {})}),
#         10: ('ateloprosopia',
#          {12: ('hymenomycete', {11: ('multinervose', {})}),
#           11: ('insomnolency', {}),
#           4: ('mesoprosopic', {}),
#           9: ('microscopics', {9: ('natrojarosite', {})}),
#           10: ('siphonostele', {10: ('uranoscopidae', {})})}),
#         12: ('autobiography',
#          {11: ('borotungstate',
#            {10: ('bronchophony',
#              {8: ('perineostomy', {}),
#               10: ('salpingostomy', {9: ('tenonostosis', {})})}),
#             9: ('lodginghouse', {})}),
#           9: ('chronotropic', {5: ('nonisotropic', {})}),
#           12: ('rhabdocoelous', {})}),
#         13: ('bromhidrosis',
#          {9: ('labidophorous', {10: ('trichinopoly', {})})}),
#         9: ('businesslike',
#          {9: ('obliviscible', {}), 8: ('omninescient', {})}),
#         8: ('podocarpaceae', {})}),
#       8: ('decommission',
#        {8: ('definitiones', {}),
#         7: ('demisemitone', {}),
#         10: ('predominately', {}),
#         1: ('recommission', {})}),
#       13: ('hemomanometer',
#        {10: ('luminousness', {10: ('thiophosgene', {})}),
#         3: ('pneomanometer', {}),
#         12: ('pruinescence', {}),
#         11: ('siphonophore', {10: ('unburdensome', {})})})}),
#     10: ('accommodative',
#      {9: ('actinidiaceae',
#        {10: ('apportionable',
#          {10: ('bromoiodized', {}),
#           11: ('cognomination',
#            {10: ('geometricize', {}), 9: ('indefinitive', {})}),
#           12: ('disinfective', {})}),
#         11: ('argumentatory',
#          {9: ('brombenzamide',
#            {9: ('prenomination', {1: ('pronomination', {})})}),
#           10: ('nonnomination', {})}),
#         6: ('artocarpaceae', {}),
#         9: ('autoinduction', {}),
#         7: ('eupomatiaceae', {}),
#         12: ('thomsenolite', {})}),
#       10: ('aerotonometer',
#        {2: ('aerotonometry', {}),
#         11: ('albuminaturia',
#          {11: ('autoxidizable', {}),
#           12: ('gynodioecism', {10: ('obcompressed', {})}),
#           7: ('illuministic', {}),
#           9: ('monomineralic', {})}),
#         10: ('amidofluoride',
#          {10: ('antimonarchic', {11: ('rhodomelaceae', {})}),
#           12: ('bromethylene', {10: ('polemoniaceae', {})}),
#           9: ('candolleaceae', {}),
#           11: ('carbosilicate',
#            {11: ('incontinence', {1: ('uncontinence', {})}),
#             10: ('podostemaceae', {})})}),
#         9: ('autoinhibited',
#          {8: ('becrinolined', {}),
#           12: ('bromobenzene', {}),
#           10: ('thiotungstate', {})}),
#         12: ('diminutivize', {})}),
#       11: ('alloeostropha',
#        {10: ('aluminoferric', {11: ('protoneurone', {})}),
#         11: ('antiprinciple',
#          {11: ('boogiewoogie', {11: ('landownership', {})})}),
#         12: ('beggiatoaceae',
#          {11: ('isolinolenic', {}),
#           12: ('laboriousness', {12: ('redefinition', {})}),
#           13: ('nasosinusitis', {})}),
#         13: ('burmanniaceae',
#          {10: ('interindicate', {}),
#           11: ('medicinelike', {3: ('undivinelike', {})})}),
#         6: ('pogonotrophy', {})}),
#       8: ('anatomization',
#        {11: ('excommunicate',
#          {9: ('macromolecule', {}), 2: ('recommunicate', {})})}),
#       12: ('antiepiscopal',
#        {4: ('chorepiscopal', {}),
#         11: ('fuliginosity',
#          {9: ('griffinesque', {}),
#           10: ('indefensible',
#            {10: ('subconscious', {}), 1: ('undefensible', {})}),
#           4: ('libidinosity', {}),
#           12: ('obmutescence', {})}),
#         10: ('oblivescence',
#          {10: ('solenostomid', {2: ('solenostomus', {})})}),
#         9: ('obliviscence', {}),
#         12: ('peruginesque', {})}),
#       7: ('recombination', {6: ('recompensive', {})})}),
#     12: ('actiniochrome',
#      {9: ('administrator',
#        {11: ('archprotopope',
#          {8: ('chromoisomer', {}),
#           10: ('counterslope', {}),
#           12: ('odontoschism', {6: ('sadomasochism', {})})}),
#         8: ('diminishment', {}),
#         7: ('unministered', {})}),
#       8: ('aluminiferous',
#        {11: ('chondriosome', {10: ('syringocoele', {})}),
#         12: ('chondrophore', {5: ('scolopophore', {})}),
#         5: ('hominivorous', {}),
#         10: ('teutonophobe', {})}),
#       10: ('amphiprostyle',
#        {12: ('andromorphous',
#          {10: ('chroococcoid',
#            {11: ('obtusilobous', {}), 3: ('protococcoid', {})}),
#           12: ('dactyloscopic', {}),
#           11: ('palaeoniscoid', {})}),
#         11: ('aneroidograph',
#          {12: ('commissioner', {10: ('puddinghouse', {})}),
#           11: ('countercoupe',
#            {10: ('indehiscence', {}), 12: ('semimonopoly', {})}),
#           10: ('hereinbefore', {}),
#           9: ('parasitotropy', {})}),
#         9: ('anthroposophy', {10: ('termitophile', {})}),
#         10: ('archbishopess',
#          {10: ('chromosphere', {8: ('photocompose', {})}),
#           12: ('somniloquize', {})}),
#         8: ('brevirostrate', {}),
#         13: ('leguminiform', {})}),
#       11: ('anomalousness',
#        {9: ('anomorhomboid',
#          {10: ('incomposedly', {}), 9: ('parhomologous', {})}),
#         11: ('bromocyanogen',
#          {11: ('collodiotype',
#            {12: ('demibastioned', {}),
#             9: ('discomposure',
#              {8: ('intromissive', {}), 10: ('laemodipodous', {})}),
#             10: ('endosiphonate', {}),
#             11: ('unremissible', {})}),
#           12: ('inequicostate', {11: ('maladminister', {})}),
#           10: ('intromission', {}),
#           9: ('isorosindone', {})}),
#         10: ('chromatophile',
#          {7: ('chromidrosis', {}),
#           10: ('levolimonene', {}),
#           9: ('noncomposite', {6: ('uncomposeable', {})})}),
#         12: ('demonographer',
#          {11: ('ducklingship',
#            {11: ('microscopist',
#              {6: ('stereoscopic', {}), 7: ('stethoscopic', {})})}),
#           12: ('orthopinacoid',
#            {12: ('subdivisible', {10: ('triplicostate', {})})})}),
#         13: ('microscopium', {}),
#         8: ('unhomologous', {})}),
#       6: ('bottomchrome', {}),
#       12: ('chromatograph',
#        {11: ('expromission',
#          {9: ('hydroscopist', {}),
#           12: ('tracheoscopic', {}),
#           10: ('uncompassable', {6: ('uncompulsory', {})}),
#           11: ('voluminously', {})}),
#         10: ('provisorship', {}),
#         12: ('pseudoscopic', {10: ('somnolescent', {})})}),
#       7: ('hymeniophore', {9: ('mackintoshite', {})}),
#       13: ('ombudsmanship', {11: ('predominantly', {})})}),
#     9: ('actinomycotic',
#      {9: ('aminoacidemia', {9: ('criminogenic', {})}),
#       11: ('argumentative',
#        {7: ('carvomenthene', {}), 10: ('indimensional', {})}),
#       10: ('autodigestion',
#        {10: ('ratiocinatory', {9: ('rhabdomantist', {})})}),
#       8: ('autoinfection', {}),
#       12: ('bronchiocele',
#        {10: ('endogenously', {9: ('sodomitically', {})}),
#         9: ('obsolescence', {}),
#         11: ('pandemoniacal',
#          {9: ('pedometrician', {}), 10: ('pelomedusidae', {})})})}),
#     8: ('administerial',
#      {9: ('amidoguaiacol',
#        {11: ('atomistically', {}), 10: ('bidimensional', {})}),
#       10: ('aplodontiidae',
#        {9: ('avicenniaceae',
#          {10: ('diagnosticate', {}), 8: ('narcomaniacal', {})}),
#         8: ('phlogisticate', {4: ('prognosticate', {})}),
#         10: ('pyrognostics', {})}),
#       11: ('biometricist',
#        {11: ('ratiocination', {2: ('ratiocinative', {})})})}),
#     13: ('conidiophore',
#      {9: ('crebricostate', {}),
#       11: ('dermatocoptes',
#        {10: ('leptoprosopy', {}),
#         9: ('phylloscopus', {}),
#         7: ('thermocouple', {})}),
#       8: ('dolichoblond',
#        {10: ('echinochrome', {}),
#         9: ('somniloquous', {10: ('teleutospore', {})})}),
#       10: ('euchromosome',
#        {9: ('hepaticostomy',
#          {9: ('hydrobiology', {}),
#           11: ('hydroquinone', {}),
#           8: ('unphilosophy', {})}),
#         10: ('multicoccous',
#          {11: ('permissioned', {}), 7: ('vermiformous', {})}),
#         8: ('quadricostate', {}),
#         6: ('unfrolicsome', {})}),
#       1: ('gonidiophore', {}),
#       7: ('inductophone',
#        {5: ('pneumatophore', {}),
#         9: ('preindispose', {}),
#         7: ('spermatophore', {7: ('syphilophobe', {})})})}),
#     7: ('hydromantical',
#      {9: ('monogynoecial', {}),
#       7: ('paedometrical', {7: ('radioscopical', {})})})}),
#   10: ('abiologically',
#    {6: ('aboriginality',
#      {7: ('agonistically',
#        {3: ('apodictically', {}), 5: ('jacobinically', {})})}),
#     10: ('abortifacient',
#      {12: ('accelerograph',
#        {11: ('acropathology',
#          {11: ('basichromiole',
#            {11: ('chirognostic', {}),
#             10: ('collodionize', {}),
#             12: ('exomologesis', {6: ('homoeogenous', {})}),
#             8: ('thiochloride', {})}),
#           13: ('bimillionaire', {}),
#           9: ('chirotonsory',
#            {8: ('chromidiogamy', {7: ('chronologize', {})})}),
#           8: ('chromatopathy',
#            {9: ('colopexotomy', {}), 11: ('technicology', {})}),
#           10: ('chromogenous', {8: ('paromologetic', {})}),
#           12: ('fibrospongiae',
#            {10: ('incommunicado', {}),
#             11: ('inconversable',
#              {6: ('uncollapsible', {}), 5: ('uncomfortable', {})}),
#             9: ('philosopheme', {}),
#             8: ('philosophize', {}),
#             12: ('unconversable', {})})}),
#         12: ('allopolyploid',
#          {2: ('autopolyploid', {}),
#           6: ('chromolipoid', {}),
#           12: ('cylindricule',
#            {11: ('endoabdominal', {8: ('thrombokinase', {})}),
#             9: ('incondensable',
#              {10: ('libidinously', {}),
#               1: ('uncondensable', {}),
#               8: ('undivorceable', {})}),
#             10: ('precomplicate',
#              {7: ('recommendable', {}),
#               10: ('ridiculosity', {}),
#               9: ('uncommendable', {}),
#               8: ('uncompaniable', {})})}),
#           10: ('cynogenealogy',
#            {10: ('entomogenous', {}),
#             11: ('hemoconiosis',
#              {1: ('hemokoniosis', {}),
#               7: ('homozygosity', {}),
#               9: ('melolonthidae', {1: ('melolonthinae', {})})}),
#             6: ('hydrogeology', {}),
#             8: ('phytobiology', {}),
#             12: ('rhabdocoelida', {11: ('seropositive', {})})}),
#           11: ('hippoglosinae',
#            {10: ('incompletable', {11: ('undenominated', {})}),
#             12: ('paurometaboly',
#              {9: ('pyroligneous', {12: ('uncompellable', {})})}),
#             11: ('plasmodiocarp', {12: ('uncompletable', {})}),
#             9: ('semiglorious', {})}),
#           13: ('physicosocial', {12: ('subcommissary', {})})}),
#         13: ('benzimidazole',
#          {12: ('biosynthesis',
#            {2: ('biosynthetic', {}),
#             11: ('pulmonectomy', {}),
#             9: ('vaginomycosis', {})}),
#           11: ('dipsomaniacal',
#            {10: ('endoconidium', {1: ('endogonidium', {})}),
#             3: ('russomaniacal', {}),
#             13: ('salpingectomy', {}),
#             11: ('unpossessable', {})}),
#           9: ('nitrobenzole',
#            {10: ('nonindictable', {8: ('undisguisable', {})}),
#             9: ('unimpoisoned', {})}),
#           10: ('unappointable', {})}),
#         10: ('ceremonialize',
#          {12: ('homoeomorphy', {}),
#           11: ('rachiglossate', {12: ('undeliverable', {})})}),
#         8: ('stomatography', {})}),
#       9: ('acetonization',
#        {9: ('achromobacter',
#          {7: ('acrothoracica', {}),
#           9: ('ascothoracica', {}),
#           11: ('autocriticism', {11: ('labiopalatine', {})})}),
#         8: ('admonitionist',
#          {10: ('agglutinative', {}), 8: ('autoantitoxin', {})}),
#         12: ('ambitiousness', {}),
#         10: ('ampelidaceous',
#          {11: ('associability', {11: ('decorticosis', {})})}),
#         7: ('approximative',
#          {9: ('associational', {}), 5: ('authoritative', {})}),
#         5: ('deodorization', {4: ('epidotization', {})}),
#         4: ('economization', {5: ('vacuolization', {})}),
#         11: ('odontotechny', {9: ('parotidectomy', {})})}),
#       11: ('acrocephalous',
#        {8: ('acrochordidae',
#          {1: ('acrochordinae', {}),
#           9: ('allothogenous', {}),
#           11: ('urolithology', {})}),
#         10: ('actinotherapy',
#          {10: ('adrenalectomy',
#            {11: ('agglomerative', {11: ('chronographer', {})}),
#             12: ('antisepticize', {}),
#             10: ('hallucinatory', {})}),
#           11: ('allochromatic',
#            {11: ('hypomochlion', {}), 8: ('indoctrinator', {})}),
#           9: ('allotriophagy', {}),
#           8: ('aminoethionic', {12: ('autoconverter', {})}),
#           12: ('androgonidium',
#            {10: ('chlorococcus', {11: ('duodenectomy', {})}),
#             11: ('colopuncture', {})}),
#           7: ('autotelegraph', {})}),
#         12: ('alchemistical',
#          {11: ('aminoaciduria',
#            {12: ('chloronitrate', {10: ('unvolitioned', {})}),
#             10: ('expositorily',
#              {9: ('holoquinonic', {11: ('incorrodible', {})})})}),
#           9: ('amphicyonidae',
#            {11: ('chlorospinel', {}), 12: ('unblemishable', {})}),
#           10: ('arsenobismite',
#            {10: ('mastodontidae',
#              {12: ('oecumenicity', {}), 11: ('philippicize', {})}),
#             11: ('nakomgilisala',
#              {10: ('pantodontidae',
#                {10: ('quadrinominal', {6: ('tuboabdominal', {})}),
#                 11: ('quadriplicate', {})})}),
#             9: ('unconfiscated', {})}),
#           5: ('encomiastical', {}),
#           12: ('holosiderite', {8: ('melolonthine', {})}),
#           8: ('irremissibly', {}),
#           13: ('unbloodiness', {})}),
#         11: ('alcoholometer',
#          {10: ('anthophoridae',
#            {10: ('aphototropism', {11: ('ramosopinnate', {})}),
#             12: ('cardiodilator',
#              {11: ('chlorococcum', {10: ('photosensory', {})})}),
#             11: ('photokinesis', {10: ('uncommingled', {})}),
#             9: ('rhinolophine', {}),
#             8: ('saurodontidae', {})}),
#           11: ('auxosubstance',
#            {12: ('parthenocarpy', {}), 9: ('unpostponable', {})}),
#           9: ('demonologist',
#            {4: ('entomologist', {}), 9: ('fluoroformol', {})}),
#           12: ('fibromuscular',
#            {10: ('formonitrile',
#              {10: ('hydrodictyon', {}), 8: ('promissorily', {})}),
#             9: ('hydrometrical', {}),
#             11: ('mastoidectomy', {})}),
#           13: ('metromaniacal', {11: ('myringectomy', {})})}),
#         9: ('ammocoetiform',
#          {10: ('amphitrichous',
#            {8: ('anisognathous', {}),
#             10: ('astrotheology', {}),
#             11: ('protozoology', {}),
#             9: ('unsolicitous', {})}),
#           9: ('armouchiquois', {}),
#           7: ('autocoenobium', {})}),
#         5: ('andropetalous', {}),
#         6: ('anomophyllous', {}),
#         2: ('autocephalous', {}),
#         13: ('basidiomycete',
#          {11: ('diminutively',
#            {10: ('fibrinolytic', {}),
#             11: ('gelatinizable', {11: ('mediosilicic', {})}),
#             7: ('indefinitely', {4: ('unfemininely', {})}),
#             8: ('indistinctly',
#              {9: ('nonignitible', {}), 1: ('undistinctly', {})})}),
#           10: ('obsequiosity', {10: ('sigmoidopexy', {})}),
#           6: ('oidiomycotic', {})})}),
#       6: ('admortization', {}),
#       10: ('aeromaechanic',
#        {9: ('agglomeration',
#          {9: ('autoeducative', {}),
#           11: ('emollescence', {}),
#           10: ('sporomycosis', {}),
#           12: ('tonicoclonic', {})}),
#         12: ('altingiaceous',
#          {12: ('burdensomely',
#            {11: ('chloroiodide', {10: ('objectionable', {})}),
#             12: ('protosilicate', {})}),
#           9: ('doloriferous', {11: ('uninvincible', {})}),
#           11: ('floriculture',
#            {11: ('orthosilicate', {}), 10: ('subtriplicate', {})}),
#           10: ('lycopodiaceae', {10: ('nicotineless', {})})}),
#         11: ('anticipatable',
#          {11: ('apocentricity',
#            {10: ('chlorocalcite', {}),
#             9: ('cinchonicine', {}),
#             12: ('magnoliaceous', {})}),
#           12: ('appropinquity',
#            {10: ('incontinency', {11: ('protosilicon', {})}),
#             8: ('subprovincial', {})}),
#           10: ('aquifoliaceae',
#            {9: ('dolichofacial', {}),
#             10: ('epitomization', {}),
#             7: ('papilionaceae', {})})}),
#         10: ('antinomianism',
#          {12: ('belligerence', {}),
#           11: ('excommunicant',
#            {12: ('haemodoraceae', {}), 11: ('monostichous', {})})}),
#         13: ('molluginaceae', {7: ('obligingness', {})})}),
#       8: ('agglutination',
#        {9: ('alantolactone', {}),
#         6: ('approximation',
#          {5: ('authorization', {}), 6: ('autoepilation', {})}),
#         10: ('artificialize', {12: ('boraginaceous', {})}),
#         7: ('diabolization', {})}),
#       7: ('aromatization', {}),
#       13: ('chromotherapy',
#        {10: ('decompoundly',
#          {10: ('idiomorphous', {10: ('pneumonopathy', {})}),
#           9: ('ileocolotomy', {}),
#           11: ('thiophosphate', {})}),
#         12: ('diploglossate',
#          {10: ('indigenously', {}), 12: ('unvoluminous', {})}),
#         11: ('ethnobiology',
#          {5: ('palaeobiology', {}),
#           11: ('sulphozincate', {}),
#           9: ('visuosensory', {})})})}),
#     9: ('absorbability',
#      {10: ('accommodately',
#        {11: ('aerodynamical',
#          {11: ('chlorozincate', {}),
#           9: ('habronemiasis', {}),
#           13: ('limnobiology', {})}),
#         8: ('alcoholometry', {}),
#         10: ('anomalistical',
#          {10: ('anorthography', {10: ('antodontalgic', {})}),
#           12: ('arteriography',
#            {10: ('bibliopolery', {}), 12: ('diplomatology', {})}),
#           8: ('astrometrical', {9: ('scholasticate', {})}),
#           11: ('autoecholalia', {11: ('tailorization', {})})})}),
#       11: ('acetometrical',
#        {11: ('acidification',
#          {2: ('alodification', {}),
#           11: ('anisopogonous',
#            {12: ('dysoxidizable', {}), 11: ('protohistory', {})}),
#           13: ('homotonously', {})}),
#         10: ('alcoholomania',
#          {12: ('anisostichous', {10: ('radiomuscular', {})}),
#           9: ('aristolochine', {11: ('uncomplicated', {})}),
#           11: ('unbecomingly', {})}),
#         9: ('algiomuscular',
#          {10: ('amygdonitrile', {}), 11: ('benzonitrile', {})}),
#         2: ('anemometrical', {}),
#         8: ('aphrodisiacal',
#          {8: ('labyrinthical', {}),
#           7: ('panlogistical', {}),
#           9: ('sacroinguinal', {})}),
#         12: ('bivoluminous',
#          {11: ('frolicsomely',
#            {12: ('labialization', {}),
#             9: ('siphonostely', {10: ('unabolishable', {})}),
#             10: ('variolization', {})}),
#           9: ('homogonously',
#            {3: ('monotonously', {}), 9: ('spongicolous', {})}),
#           8: ('ubiquitously', {})}),
#         3: ('pantometrical', {2: ('tautometrical', {})})}),
#       7: ('achromaticity', {8: ('associatively', {})}),
#       12: ('acidimetrical',
#        {10: ('aminodiphenyl', {10: ('nonintoxicant', {})}),
#         6: ('amphimictical', {}),
#         12: ('bibliographer',
#          {10: ('diplococcoid', {}),
#           12: ('feminologist',
#            {2: ('luminologist', {}), 12: ('unconfiscable', {})}),
#           11: ('fuliginously',
#            {11: ('nonoxidizable', {}), 12: ('protococcales', {})})}),
#         13: ('bignoniaceous', {}),
#         7: ('chiromantical', {}),
#         11: ('chroococcales', {10: ('silicicolous', {})}),
#         4: ('eudiometrical', {}),
#         9: ('hydroscopical', {3: ('microscopical', {})}),
#         8: ('quadrinomical', {})}),
#       9: ('admonishingly',
#        {2: ('astonishingly', {}),
#         10: ('autoeroticism',
#          {9: ('caudotibialis', {}),
#           11: ('historiology',
#            {4: ('microbiology', {}), 9: ('prodigiosity', {})})})}),
#       6: ('indocibility', {}),
#       13: ('paniconograph', {11: ('semifloscular', {})}),
#       8: ('pathogenicity', {})}),
#     11: ('accommodating',
#      {2: ('accommodation', {}),
#       7: ('accompaniment',
#        {9: ('acetomorphine', {}),
#         8: ('discomposing', {9: ('recompilation', {})}),
#         7: ('saccomyoidean', {9: ('uncomprising', {})})}),
#       10: ('acetothienone',
#        {10: ('actiniomorpha',
#          {6: ('actinocarpous', {}),
#           7: ('actinodromous', {7: ('cynomorphous', {})}),
#           9: ('anticorrosion',
#            {11: ('archidiaconal',
#              {12: ('delomorphous',
#                {2: ('mesomorphous', {2: ('xeromorphous', {})}),
#                 3: ('pleomorphous', {})})}),
#             10: ('arthrodonteae', {}),
#             9: ('clonicotonic', {})}),
#           11: ('aurotellurite',
#            {12: ('entoproctous',
#              {10: ('microconodon', {}), 9: ('venomousness', {})}),
#             9: ('fibromembrane', {}),
#             7: ('talcochlorite', {}),
#             11: ('trilinolenin', {})}),
#           12: ('butyrolactone',
#            {11: ('homoarecoline',
#              {9: ('rhombogenous', {}), 11: ('thecoglossate', {})}),
#             12: ('hormonogenic', {10: ('phenomenalize', {})}),
#             10: ('hypotrochoid',
#              {12: ('overmoisture', {}), 9: ('postpositive', {})})}),
#           13: ('endorhinitis', {10: ('lycopersicon', {})}),
#           10: ('monzodiorite', {8: ('siphonorhine', {})}),
#           8: ('tautomorphous', {})}),
#         8: ('actinocrinite',
#          {5: ('ambatoarinite', {}),
#           8: ('anthochlorine', {}),
#           11: ('chloroacetone', {})}),
#         9: ('actinotoxemia',
#          {11: ('adelomorphous',
#            {12: ('apportionment', {10: ('unconfidence', {})}),
#             11: ('chondriocont', {8: ('chymosinogen', {})})}),
#           10: ('amidocaffeine',
#            {9: ('aphrosiderite', {10: ('heliotropine', {})}),
#             11: ('chromocenter', {}),
#             8: ('dinornithine', {})}),
#           9: ('anthosiderite', {12: ('vaccinogenous', {})}),
#           12: ('complexioned', {11: ('malconvenance', {})})}),
#         11: ('amphipodiform',
#          {11: ('anisometropia',
#            {1: ('anisometropic', {}),
#             8: ('anticorrosive', {}),
#             9: ('chromophoric',
#              {7: ('entomophthora', {}), 8: ('vaccinophobia', {})}),
#             11: ('conconscious',
#              {10: ('examinational', {}),
#               8: ('homomorphous', {11: ('incoincident', {})}),
#               9: ('hylomorphous',
#                {2: ('pyromorphous', {2: ('zygomorphous', {})}),
#                 4: ('tauromorphous', {})}),
#               11: ('laudification',
#                {12: ('pleosporaceae', {}), 5: ('vandalization', {})})}),
#             10: ('dandification',
#              {12: ('eidoptometry', {10: ('promontoried', {})})}),
#             12: ('exterminatory',
#              {9: ('hallucination', {}),
#               11: ('hypofunction', {}),
#               10: ('sabbatization', {}),
#               8: ('sermocination', {})})}),
#           10: ('antivibratory',
#            {11: ('apogeotropism',
#              {8: ('hypoisotonic', {}),
#               11: ('monomorphous', {10: ('panharmonicon', {})})}),
#             12: ('archhypocrite',
#              {12: ('isonicotinic', {}), 9: ('unmonopolize', {})}),
#             9: ('atheromatosis', {}),
#             8: ('atticomastoid', {})}),
#           9: ('asthenobiotic', {}),
#           12: ('autocytolysis',
#            {12: ('azurmalachite',
#              {12: ('cometographer',
#                {11: ('podsolization', {1: ('podzolization', {})})}),
#               10: ('disconducive', {12: ('pachyglossate', {})}),
#               11: ('domesticative',
#                {11: ('gyrophoraceae', {}),
#                 8: ('ilmenorutile', {}),
#                 10: ('monotropaceae', {})}),
#               8: ('hydroboracite', {})}),
#             11: ('bloodshotten',
#              {10: ('chromophobic',
#                {8: ('holoproteide', {}), 11: ('tylostomaceae', {})}),
#               11: ('demonolatrous', {12: ('tachyglossate', {})})}),
#             13: ('cladodontidae', {10: ('londonization', {})}),
#             10: ('entomophagous',
#              {10: ('paurometabola', {}),
#               11: ('thiotungstic', {}),
#               9: ('uncomeliness', {})})}),
#           13: ('borotungstic',
#            {9: ('hydrogenation', {}), 11: ('pyromorphidae', {})})}),
#         12: ('anomalopteryx',
#          {10: ('antambulacral',
#            {12: ('comicotragedy', {}), 11: ('monomolybdate', {})}),
#           11: ('arterioarctia',
#            {8: ('cardiomalacia', {}),
#             11: ('coincorporate', {10: ('monogenistic', {})}),
#             9: ('promonarchist', {})}),
#           12: ('fibrinolysin',
#            {12: ('hallucinative', {}),
#             8: ('isoindigotin', {}),
#             10: ('misogynistic', {})}),
#           13: ('hypopinealism', {})}),
#         13: ('endobronchial',
#          {11: ('rudimentarily', {2: ('sedimentarily', {})})})}),
#       9: ('acetylglycine',
#        {11: ('actinomorphic',
#          {9: ('alloisomerism', {9: ('entomotomist', {})}),
#           12: ('assassination',
#            {7: ('disseminative', {}), 11: ('unconductive', {})}),
#           11: ('autohypnotism',
#            {10: ('calciobiotite', {}),
#             11: ('primrosetide',
#              {1: ('primrosetime', {}), 11: ('unblemishing', {})})}),
#           10: ('ectoproctous', {10: ('unlocomotive', {})}),
#           7: ('paedomorphism',
#            {1: ('pedomorphism', {}), 5: ('pyromorphite', {})}),
#           13: ('preordination', {5: ('subordinative', {})})}),
#         10: ('allophanamide',
#          {9: ('antisiccative', {}),
#           8: ('assassinative', {}),
#           11: ('autohemolysis', {}),
#           10: ('theomorphize', {})}),
#         12: ('antimiasmatic',
#          {8: ('apposiopestic', {}),
#           10: ('carbonization',
#            {7: ('dissemination',
#              {6: ('nonordination', {}), 3: ('prosemination', {})}),
#             2: ('harmonization', {2: ('jargonization', {})}),
#             3: ('mammonization', {3: ('patronization', {})}),
#             11: ('thrombogenic', {})}),
#           12: ('communistery',
#            {10: ('mucormycosis', {}), 8: ('subcommittee', {})}),
#           11: ('disordination',
#            {11: ('endomorphism', {}),
#             1: ('misordination', {}),
#             3: ('subordination', {})}),
#           9: ('mangonization',
#            {5: ('radiumization', {}), 7: ('sublimitation', {})}),
#           13: ('reconnoitrer', {})}),
#         9: ('autocytolytic',
#          {11: ('decongestive', {8: ('mediopontine', {})})}),
#         13: ('incompensated',
#          {8: ('incriminatory', {}),
#           10: ('recriminatory', {11: ('thrombostasis', {})}),
#           1: ('uncompensated', {})}),
#         8: ('proscolecine', {})}),
#       8: ('acroceratidae',
#        {8: ('aeromechanics',
#          {10: ('factorization', {2: ('lactonization', {})}),
#           9: ('macrosporange', {})}),
#         10: ('autohemolysin', {2: ('autohemolytic', {})}),
#         9: ('combinational', {8: ('narcotization', {})}),
#         11: ('leiomyomatous',
#          {10: ('uncomminuted', {6: ('uncommonplace', {})}),
#           12: ('unconvincing', {})}),
#         12: ('noncommonable', {})}),
#       11: ('actinophorous',
#        {2: ('actinopterous', {}),
#         9: ('adenocancroid',
#          {11: ('allothigenous',
#            {11: ('entropionize', {}),
#             8: ('incontinuous', {1: ('uncontinuous', {})}),
#             9: ('lochiocolpos', {9: ('nonmonogamous', {})}),
#             10: ('nonmelodious', {})}),
#           10: ('angiostenosis',
#            {10: ('anticonductor', {11: ('gerontogeous', {})}),
#             11: ('cinchonology', {10: ('pneumococcus', {})}),
#             9: ('inconcinnous', {})}),
#           9: ('mesotrochous',
#            {8: ('nonconscious', {}),
#             10: ('syenodiorite', {6: ('zonochlorite', {})})}),
#           8: ('monochloride', {})}),
#         8: ('adenofibrosis',
#          {9: ('alectoropodes', {}),
#           10: ('aplostemonous',
#            {6: ('apometabolous', {}),
#             9: ('atrabilarious', {9: ('unimpostrous', {})}),
#             8: ('homoeomerous', {7: ('monotrochous', {})}),
#             7: ('spermogonous', {8: ('telotrochous', {})})}),
#           6: ('asthenobiosis', {}),
#           11: ('omnivoracious',
#            {9: ('podocephalous', {7: ('protanomalous', {})})})}),
#         11: ('alectrionidae',
#          {11: ('ambagiousness',
#            {11: ('amidoaldehyde',
#              {12: ('bronchogenic', {10: ('thigmotropic', {})}),
#               11: ('pneumonopexy', {})}),
#             10: ('blastomycosis',
#              {11: ('cardiokinetic', {11: ('colossuswise', {})}),
#               12: ('fibrinogenic', {12: ('gymnoglossate', {})}),
#               8: ('neuromimesis', {}),
#               10: ('pseudoscines', {})}),
#             13: ('chloroformate',
#              {10: ('cuprosilicon', {10: ('natrochalcite', {})}),
#               12: ('oligometochia', {}),
#               11: ('sensorimotor', {})}),
#             12: ('colipuncture',
#              {12: ('desmidiology', {10: ('pneumococcic', {})}),
#               11: ('hypophosphate',
#                {2: ('pyrophosphate', {2: ('zymophosphate', {})})})}),
#             5: ('eximiousness', {}),
#             9: ('homeokinesis', {}),
#             7: ('laborsomeness', {})}),
#           10: ('amphodiplopia',
#            {10: ('anemobiagraph', {}),
#             11: ('autoschediaze',
#              {12: ('dactylioglyph', {}),
#               10: ('fluophosphate', {}),
#               11: ('unvindictive', {})})}),
#           9: ('borofluoride',
#            {10: ('denicotinize', {}),
#             8: ('holocentroid', {}),
#             11: ('retromingent', {10: ('unempoisoned', {})})}),
#           12: ('dermomycosis',
#            {9: ('dolorousness', {8: ('monogenesist', {})}),
#             11: ('emblematology', {12: ('rhododendron', {})}),
#             12: ('homoveratrole', {}),
#             4: ('hyphomycosis', {}),
#             10: ('monolinguist', {10: ('pyropuncture', {})}),
#             8: ('odontosyllis', {})}),
#           7: ('lanthanotidae', {}),
#           13: ('monimostylic', {})}),
#         7: ('allochthonous',
#          {9: ('anticlinorium', {}),
#           10: ('opsonophoric', {}),
#           6: ('unmonotonous', {})}),
#         12: ('anacardiaceae',
#          {3: ('araucariaceae', {}),
#           7: ('asphodelaceae', {}),
#           12: ('benzotoluide',
#            {9: ('broncobuster', {9: ('pyrobelonite', {})}),
#             11: ('fluozirconic',
#              {9: ('hydrokinetic', {}), 11: ('viscountship', {})}),
#             12: ('triumvirship', {})}),
#           11: ('bismuthinite',
#            {9: ('brilliolette', {11: ('nightingalize', {})}),
#             10: ('companionable',
#              {10: ('foreconceive', {9: ('recontinuance', {})}),
#               11: ('tristigmatose', {}),
#               7: ('unopinionated', {})}),
#             13: ('proximobuccal', {}),
#             11: ('uncounselled', {})}),
#           10: ('brongniardite',
#            {10: ('concrescible', {7: ('inconscience', {})}),
#             11: ('mathematicize', {}),
#             8: ('promagistrate', {}),
#             7: ('provincialize', {}),
#             12: ('unbodiliness',
#              {8: ('undemolished', {}), 3: ('unhomeliness', {})})}),
#           6: ('caryocaraceae', {8: ('nyctaginaceae', {})}),
#           8: ('cymodoceaceae',
#            {7: ('geoglossaceae', {7: ('meridionaceae', {})}),
#             8: ('theligonaceae', {})}),
#           9: ('individualize', {7: ('indoctrinize', {})}),
#           13: ('somnivolency', {})}),
#         10: ('archbishopric',
#          {11: ('autohexaploid',
#            {12: ('chemokinesis',
#              {10: ('dexiotropism', {10: ('thyroidotomy', {})}),
#               9: ('fibrinolysis', {}),
#               6: ('iridodonesis', {})}),
#             10: ('ectocuniform', {10: ('fluochloride', {})}),
#             11: ('gastromycosis',
#              {13: ('hellenophile', {}),
#               11: ('hypochlorite', {10: ('oophorostomy', {})})}),
#             13: ('schizomycete', {})}),
#           10: ('bronchomotor',
#            {11: ('cardioschisis', {11: ('dinornithoid', {})}),
#             10: ('holosiphonate',
#              {11: ('schoolboydom', {}),
#               8: ('siliciophite', {}),
#               10: ('siphonozooid', {})})}),
#           9: ('cardiotrophia', {6: ('oligotrophic', {})}),
#           12: ('disinfection',
#            {11: ('paleopedology', {}), 9: ('underopinion', {})}),
#           13: ('ptenoglossate', {})}),
#         6: ('autochthonous', {9: ('echinococcus', {})}),
#         13: ('bridemaidship',
#          {12: ('deorientalize',
#            {10: ('dorsabdominal', {11: ('overminutely', {})}),
#             11: ('incoalescence', {11: ('monomastigate', {})}),
#             9: ('nemalionaceae', {}),
#             12: ('postabdominal', {})}),
#           13: ('ebulliometer',
#            {11: ('fluotantalate', {}),
#             12: ('homogangliate', {7: ('pyrotantalate', {})})}),
#           10: ('emblematicize', {9: ('unfemininity', {})}),
#           11: ('eriocaulaceae',
#            {11: ('hydrocinnamic', {}),
#             10: ('prereconcile', {12: ('zygomaxillare', {})})})}),
#         5: ('digonoporous', {})}),
#       12: ('amarantaceous',
#        {10: ('anatripsology',
#          {12: ('cardiogenesis',
#            {11: ('corallinaceae',
#              {10: ('frondescence', {}), 11: ('improvidence', {})}),
#             8: ('imposingness', {}),
#             12: ('juncaginaceae',
#              {11: ('silicotalcose', {}), 13: ('slobberchops', {})})}),
#           9: ('cnidophorous',
#            {11: ('pharmacognosy', {}), 10: ('phrenicotomy', {})}),
#           13: ('nidulariaceae',
#            {10: ('pyrenomycete', {8: ('serpenticide', {})}),
#             8: ('sporochnaceae', {})}),
#           10: ('paratungstate',
#            {10: ('scrutinously', {9: ('turbinectomy', {})}),
#             13: ('sonoriferous', {1: ('soporiferous', {})}),
#             12: ('ulotrichaceae', {8: ('uniridescent', {})})}),
#           11: ('podophyllous',
#            {8: ('primigenious', {}),
#             11: ('semipinacolin', {}),
#             7: ('soboliferous', {})})}),
#         12: ('angiopressure',
#          {10: ('anthropomorph',
#            {9: ('entocuniform', {9: ('underhistory', {})}),
#             11: ('indicatorinae', {12: ('subglobulose', {})}),
#             10: ('kathopanishad', {}),
#             12: ('misworshiper', {12: ('platyglossate', {})})}),
#           12: ('arsenicophagy',
#            {12: ('bourignonism',
#              {1: ('bourignonist', {}), 11: ('siphonoglyph', {})}),
#             11: ('brokenhearted',
#              {10: ('butterscotch', {11: ('urobilinogen', {})}),
#               12: ('esophagostomy', {11: ('iridocoloboma', {})}),
#               11: ('perditionable', {}),
#               8: ('proleukocyte', {})}),
#             10: ('dolichocephal',
#              {9: ('dorsoscapular', {}),
#               12: ('heresiologer', {}),
#               10: ('lymphotrophy', {12: ('proleucocyte', {})}),
#               11: ('provincialate', {}),
#               13: ('quadrifoliate', {})}),
#             9: ('ventricosity', {})}),
#           11: ('balloonflower',
#            {9: ('benzoquinone', {}),
#             12: ('eosinophilic',
#              {11: ('hemophagocyte', {7: ('reticulocyte', {})}),
#               2: ('iodinophilic', {}),
#               10: ('pediculicide', {})}),
#             10: ('galeorhinidae', {}),
#             11: ('hippoboscidae',
#              {12: ('omnicorporeal', {}), 11: ('trilinolenate', {})})}),
#           9: ('benzophenone', {}),
#           8: ('buffoonesque', {10: ('unimprisoned', {})}),
#           13: ('polygynoecial',
#            {12: ('stelliscript', {11: ('subdichotomy', {})})})}),
#         8: ('animalivorous',
#          {9: ('carbonigenous', {}),
#           8: ('hydronitrous', {}),
#           10: ('laminariaceae', {12: ('preconscious', {})})}),
#         11: ('apprehensible',
#          {11: ('bootlessness',
#            {12: ('ferrosilicon', {11: ('planirostrate', {})}),
#             11: ('probosciform', {}),
#             10: ('protistology', {7: ('protonegroid', {})}),
#             13: ('seasoninglike', {}),
#             9: ('solenostelic', {})}),
#           12: ('chlorophyceae',
#            {10: ('droopingness',
#              {10: ('odontoglossae', {}), 4: ('unlovingness', {})}),
#             11: ('magnirostrate',
#              {12: ('polariscopist', {10: ('pseudomucoid', {})}),
#               9: ('radiatoporose', {}),
#               5: ('semiprostrate', {})}),
#             13: ('nothingology', {}),
#             12: ('semifasciated',
#              {11: ('strobiliform', {}), 12: ('synosteology', {})}),
#             8: ('tristichaceae', {})}),
#           13: ('diagnostician',
#            {11: ('enantiotropic', {11: ('sanguinolency', {})}),
#             10: ('luminificent', {}),
#             13: ('multicolored', {})}),
#           10: ('fluorescence',
#            {9: ('grolieresque', {}),
#             10: ('lithocenosis', {13: ('parvirostrate', {})}),
#             11: ('pyrotheology', {}),
#             3: ('sonorescence', {})}),
#           9: ('foreconclude',
#            {9: ('oophoreocele', {10: ('precriticize', {})})})}),
#         9: ('blennogenous',
#          {9: ('diatomiferous', {9: ('pliopithecus', {})}),
#           13: ('gigartinaceae', {}),
#           7: ('immorigerous', {}),
#           11: ('myrmecochory', {}),
#           4: ('resinogenous', {}),
#           10: ('stramineously', {})}),
#         13: ('circuminsular',
#          {10: ('debituminize',
#            {10: ('holoquinoidal', {10: ('inostensible', {})}),
#             11: ('irremunerable',
#              {11: ('pseudoisomer', {}), 12: ('subperiosteal', {})})}),
#           12: ('desiliconize',
#            {6: ('endellionite', {}),
#             10: ('indigestible',
#              {11: ('physiosophic', {}),
#               8: ('predisposable', {8: ('undethronable', {})}),
#               1: ('undigestible', {}),
#               6: ('undissoluble', {})}),
#             7: ('soliloquizer', {})}),
#           11: ('disinvigorate',
#            {8: ('historiograph', {}),
#             10: ('indissoluble', {7: ('nondivisible', {})}),
#             9: ('nonumbilicate', {}),
#             11: ('redissoluble',
#              {12: ('subhorizontal', {}), 9: ('unostensible', {})}),
#             12: ('underwhistle', {})}),
#           9: ('promissionary', {}),
#           13: ('undestroyable',
#            {4: ('undevelopable', {}), 3: ('undisprovable', {})})}),
#         7: ('cladautoicous',
#          {8: ('paraconscious', {}),
#           10: ('strobilaceous', {5: ('subcoriaceous', {})})}),
#         5: ('cladoniaceous', {}),
#         6: ('dawsoniaceous', {5: ('goodeniaceous', {})})}),
#       13: ('beneighbored',
#        {11: ('brainsickness',
#          {9: ('bronchiospasm', {}),
#           10: ('cavernicolous',
#            {12: ('delitescency', {}), 9: ('disingenuous', {})}),
#           7: ('graminicolous', {}),
#           12: ('indefensibly', {12: ('tubuliporidae', {})}),
#           11: ('sesquiplicate',
#            {11: ('subdivisional',
#              {11: ('tribespeople', {}), 9: ('undiffusible', {})}),
#             9: ('suffruticose', {}),
#             12: ('undesirously', {})})}),
#         9: ('cabinetworker',
#          {10: ('indicatoridae', {9: ('insenescible', {})}),
#           11: ('nondiscovery',
#            {8: ('puddingberry', {}), 10: ('unprincipled', {})}),
#           12: ('puncticulose', {})}),
#         10: ('hemitrichous',
#          {11: ('indevirginate', {}),
#           10: ('interinvolve', {}),
#           12: ('monepiscopacy', {10: ('redeliverance', {})}),
#           9: ('reviviscible', {9: ('semipinacolic', {})})}),
#         12: ('indiscussable',
#          {3: ('indispensable', {}),
#           11: ('pristipomidae', {}),
#           1: ('undiscussable', {}),
#           4: ('undispensable', {}),
#           10: ('viridescence', {1: ('virilescence', {})})}),
#         8: ('puddingheaded', {12: ('ventriculose', {})}),
#         13: ('rhizautoicous', {})})}),
#     12: ('acetanisidide',
#      {8: ('acetylacetone',
#        {9: ('allhallowtide', {10: ('metainfective', {})}),
#         10: ('antihistamine',
#          {8: ('contaminative', {}), 11: ('paleoandesite', {})}),
#         11: ('inextensible',
#          {9: ('mistranscribe', {10: ('theraphosidae', {})}),
#           8: ('propensitude', {}),
#           11: ('rheumatismoid', {}),
#           1: ('unextensible', {})}),
#         12: ('salamandridae', {})}),
#       11: ('achromatopsia',
#        {11: ('acquiescement',
#          {10: ('anthraphenone',
#            {11: ('argumentation', {11: ('artificership', {})}),
#             12: ('composedness',
#              {10: ('declinometer',
#                {9: ('mucedinaceous', {12: ('pseudosopher', {})})}),
#               12: ('subquintuple', {})}),
#             13: ('falconiformes', {}),
#             10: ('unomnipotent', {})}),
#           9: ('archmessenger', {}),
#           11: ('armamentarium',
#            {10: ('compunctious',
#              {11: ('foraminiferan', {10: ('prosilverite', {})}),
#               10: ('precompensate', {}),
#               13: ('squamariaceae', {})}),
#             11: ('cyrtoceracone',
#              {10: ('dermoosseous',
#                {10: ('endosternite', {}), 9: ('repossession', {})}),
#               11: ('incombustion',
#                {11: ('labyrinthodon', {11: ('pucciniaceous', {})}),
#                 12: ('salviniaceous', {})}),
#               9: ('premyelocyte', {12: ('unconversion', {})}),
#               13: ('somniloquist', {})}),
#             12: ('firesideship',
#              {11: ('scorpionwort',
#                {9: ('stringcourse', {10: ('trophosphere', {})}),
#                 10: ('trochosphere', {})})})}),
#           7: ('atterminement', {}),
#           12: ('carbodynamite',
#            {8: ('carboniferous',
#              {0: ('carboniferous', {}), 10: ('mastosquamose', {})}),
#             12: ('divinityship',
#              {11: ('foraminiferal', {11: ('nonpoisonous', {})}),
#               12: ('laterifolious',
#                {13: ('pneumomassage', {}),
#                 6: ('sanctimonious', {}),
#                 12: ('uncompounded', {})}),
#               8: ('middlemanship', {}),
#               10: ('somniloquism', {10: ('tubuliporoid', {})})}),
#             9: ('ferrumination', {}),
#             11: ('galeopithecus',
#              {11: ('hyperdiastole', {}),
#               12: ('hypersystole',
#                {11: ('inconclusion',
#                  {10: ('monocentroid', {}),
#                   6: ('recompletion', {}),
#                   9: ('recordership', {}),
#                   11: ('terminational', {})}),
#                 12: ('podocarpineae', {}),
#                 13: ('unwomanliness', {})}),
#               10: ('redemptioner', {}),
#               9: ('subdititious', {}),
#               13: ('tribesmanship', {})}),
#             13: ('geometriform',
#              {10: ('pseudapospory', {11: ('spermigerous', {})})}),
#             10: ('incrimination',
#              {11: ('nonoffensive', {12: ('pharynogotome', {})}),
#               9: ('pneumonolith', {}),
#               10: ('preocclusion', {}),
#               12: ('presophomore', {9: ('subconvolute', {})}),
#               2: ('recrimination', {})})}),
#           13: ('custodianship',
#            {6: ('librarianship', {}),
#             12: ('overrigorous',
#              {9: ('prepronounce', {}), 8: ('pterygophore', {})}),
#             11: ('stomapodiform', {12: ('uncommutative', {})}),
#             10: ('uncompahgrite', {})})}),
#         10: ('anthracothere',
#          {8: ('antikenotoxin', {}),
#           10: ('arrhenotokous',
#            {7: ('arteriovenous', {6: ('heteronomous', {})}),
#             8: ('echinocereus', {}),
#             12: ('magnochromite',
#              {8: ('noncorrosive', {}), 9: ('stromeyerite', {})}),
#             10: ('pathognomonic', {}),
#             11: ('tropaeolaceae', {})}),
#           11: ('cardiectomize',
#            {9: ('circumlocute', {9: ('mermithogyne', {})}),
#             11: ('dryopithecid',
#              {11: ('isogenotypic',
#                {10: ('pedotrophist', {}), 11: ('protoelastose', {})}),
#               12: ('querimonious', {}),
#               13: ('stauromedusae', {}),
#               10: ('virtuosoship', {})}),
#             12: ('ectomesoblast',
#              {9: ('gymnosophist', {}), 12: ('pachyglossous', {})}),
#             10: ('galvanotropic',
#              {8: ('paedotrophist', {}), 10: ('paramountship', {})}),
#             13: ('pneumonodynia', {11: ('uncompressed', {})})}),
#           12: ('commonership',
#            {4: ('courtiership', {}),
#             11: ('euryprosopic',
#              {11: ('proinclusion', {}), 12: ('reaccommodate', {})}),
#             10: ('narcohypnosis',
#              {11: ('selenotropic', {}),
#               12: ('semianatropal', {10: ('vermiformity', {})})}),
#             6: ('patronessship', {}),
#             7: ('scullionship', {})}),
# ...
#             4: ('woundableness', {})}),
#           8: ('unwarlikeness', {})})}),
#       8: ('dilettanteish',
#        {1: ('dilettanteism', {}),
#         9: ('distractingly', {}),
#         12: ('infrastipular',
#          {7: ('intercellular', {9: ('paragastrular', {})}),
#           5: ('intracellular', {}),
#           6: ('periarticular', {6: ('sinuauricular', {})}),
#           9: ('pretubercular', {})}),
#         11: ('interlamellar',
#          {3: ('intermaxillar', {}), 10: ('prescapularis', {})}),
#         13: ('parvicellular', {}),
#         10: ('unreluctantly', {})}),
#       7: ('directorially',
#        {11: ('intergranular', {}),
#         10: ('multangularly', {9: ('preterregular', {})}),
#         8: ('precurricular', {}),
#         9: ('streptoneural', {})}),
#       4: ('rectangularly', {}),
#       2: ('unrectangular', {})}),
#     6: ('blanketmaking',
#      {9: ('unclustering',
#        {2: ('unfluttering', {}),
#         4: ('unsheltering', {}),
#         3: ('unstuttering', {})}),
#       8: ('unpretending', {}),
#       10: ('unsucceeding', {})}),
#     7: ('breastfeeding',
#      {11: ('conqueringly',
#        {11: ('manchesterism', {1: ('manchesterist', {})}),
#         8: ('quinqueserial', {})}),
#       7: ('housekeeping', {8: ('prenumbering', {6: ('trickstering', {})})}),
#       9: ('nonbelieving',
#        {5: ('nondegerming', {}),
#         4: ('nonreceiving', {}),
#         7: ('nonsustaining', {10: ('pawnbrokering', {})}),
#         8: ('omnirevealing',
#          {10: ('tranquilizing', {}),
#           9: ('unshuddering',
#            {3: ('unslumbering', {}), 8: ('woolgathering', {})}),
#           8: ('unsubmerging', {})}),
#         9: ('unquarrelling', {})}),
#       10: ('nondeterrent', {5: ('nonrecurring', {})}),
#       8: ('nonrefueling', {7: ('unsurfeiting', {}), 8: ('unsuspecting', {})}),
#       5: ('presuffering', {})}),
#     13: ('celestialness',
#      {11: ('cephalocaudal',
#        {10: ('ceratophyllum',
#          {11: ('chirographary',
#            {9: ('clairvoyantly', {}),
#             10: ('corporational',
#              {12: ('interscapular', {11: ('septifragally', {})}),
#               9: ('reprobatively', {})}),
#             11: ('deuteropathic', {9: ('phelloplastic', {})}),
#             12: ('gesithcundman',
#              {9: ('perilaryngeal', {}), 10: ('revibrational', {})}),
#             13: ('mesenchymatal', {10: ('metallorganic', {})})}),
#           10: ('cryptoclastic',
#            {4: ('cryptolunatic', {}),
#             12: ('diplobacillus',
#              {12: ('perigastrular', {}), 10: ('ultraparallel', {})}),
#             9: ('heptasyllabic', {}),
#             13: ('vesicupapular', {})}),
#           12: ('exclamational',
#            {7: ('exploratively', {}),
#             6: ('extraparietal', {}),
#             11: ('intervalvular', {}),
#             12: ('spectacularly', {}),
#             13: ('unpersuadably', {})}),
#           13: ('explicatively', {2: ('implicatively', {})}),
#           8: ('hematoplastic', {}),
#           7: ('keratoplastic', {7: ('neurapophysis', {})}),
#           9: ('nematoblastic', {})}),
#         11: ('coccobacillus',
#          {11: ('crescographic',
#            {10: ('erythroclasis', {10: ('physicalistic', {})}),
#             13: ('explanatively',
#              {12: ('multicellular', {}), 5: ('superlatively', {})}),
#             11: ('heterophylly',
#              {9: ('interscapulum',
#                {10: ('overtruthful', {}), 12: ('preparatively', {})}),
#               10: ('predicatively', {})}),
#             12: ('metapsychosis',
#              {13: ('polyglottally', {}),
#               11: ('supraspinatus', {11: ('temerariously', {})})}),
#             8: ('scleroblastic', {})}),
#           12: ('cryptodynamic',
#            {13: ('extravagantly',
#              {12: ('interspicular', {}), 8: ('significantly', {})}),
#             10: ('heteroblastic',
#              {6: ('prescholastic', {}), 8: ('tetrasyllabic', {})}),
#             12: ('pleuracanthea',
#              {11: ('steeplechaser', {}),
#               10: ('superblunder', {13: ('tetradrachmon', {})})})}),
#           13: ('elytroplastic',
#            {10: ('heterochromia', {}),
#             8: ('heterographic', {}),
#             4: ('heteroplastic', {}),
#             9: ('septisyllabic', {})}),
#           10: ('exclamatively',
#            {12: ('interarcualis', {9: ('luteocobaltic', {})}),
#             11: ('overlogically',
#              {11: ('postbaptismal', {}), 10: ('uteroparietal', {})}),
#             9: ('polygamically', {}),
#             6: ('prerogatively', {4: ('retroactively', {})}),
#             10: ('superficially', {})}),
#           8: ('microcephalus', {}),
#           9: ('porencephalus', {9: ('pseudoramulus', {})}),
#           7: ('pterodactylus', {})}),
#         9: ('cryptogamical',
#          {10: ('degradational',
#            {10: ('epipharyngeal',
#              {10: ('lethargically', {}), 8: ('metapophyseal', {})}),
#             12: ('leptocephalus', {0: ('leptocephalus', {})}),
#             7: ('tetradrachmal', {})}),
#           11: ('diplocephalus',
#            {2: ('hoplocephalus', {}), 9: ('photocatalyst', {})}),
#           8: ('explorational',
#            {5: ('prevocational', {}), 8: ('semipyramidal', {})})}),
#         12: ('distractively',
#          {11: ('externalistic',
#            {11: ('peripapillary', {9: ('previgilantly', {})}),
#             10: ('postbreakfast', {11: ('steatornithes', {})}),
#             8: ('ureteroplasty', {})}),
#           9: ('fissiparously',
#            {12: ('lithofracteur', {}), 9: ('precipitately', {})}),
#           12: ('hypercyanotic',
#            {7: ('hyperparoxysm', {}),
#             8: ('mesenchymatic', {10: ('perivaginitis', {})}),
#             10: ('overfrighted',
#              {10: ('stereographic', {}), 11: ('stereoplasmic', {})}),
#             12: ('phleborrhaphy', {}),
#             9: ('premegalithic', {}),
#             11: ('pseudophallic',
#              {8: ('psychoanalyst', {}), 11: ('unexcogitated', {})})}),
#           10: ('imperturbably',
#            {11: ('infraspinatus', {12: ('postpulmonary', {})}),
#             8: ('overexcitably', {}),
#             12: ('postaspirated', {}),
#             10: ('precipitantly', {}),
#             9: ('sclerophylly', {8: ('superaxillary', {})})}),
#           8: ('intermutually', {}),
#           13: ('nucleoplasmic', {9: ('plectognathic', {})})}),
#         7: ('encephalogram', {}),
#         13: ('interaxillary',
#          {11: ('multisyllabic', {9: ('postparalytic', {})}),
#           12: ('polyprismatic', {}),
#           10: ('thielaviopsis', {})})}),
#       10: ('cephaloclasia',
#        {5: ('cephalomyitis', {}),
#         11: ('correlatively',
#          {10: ('cryptovalency',
#            {10: ('eccentrically', {}), 11: ('unclassically', {})}),
#           6: ('declaratively', {}),
#           11: ('derencephalus',
#            {12: ('multivalvular', {}), 9: ('telegraphical', {})}),
#           12: ('electropathic',
#            {11: ('inexplicables', {12: ('subesophageal', {})}),
#             12: ('psilophytales', {11: ('uncalumniated', {})})}),
#           9: ('inelaborately',
#            {11: ('legislational', {}), 1: ('unelaborately', {})}),
#           5: ('legislatively', {}),
#           8: ('overpartially', {})}),
#         10: ('crystallogram',
#          {3: ('crystalloidal', {}),
#           13: ('leptodactylus',
#            {10: ('replicatively', {}), 12: ('semiasphaltic', {})}),
#           12: ('stereoplanula', {11: ('telegrammatic', {})}),
#           9: ('supercallosal', {})}),
#         9: ('cubitoplantar', {13: ('presbyacousia', {})}),
#         8: ('epithalamiast', {10: ('methylmalonic', {})}),
#         12: ('extratracheal',
#          {7: ('extravagantes', {}),
#           12: ('impressionary', {12: ('oscillatively', {})}),
#           11: ('irresolutely',
#            {12: ('pleuracanthus', {10: ('ustilaginales', {})}),
#             8: ('sclerodactyly', {}),
#             11: ('semisavagedom', {})}),
#           9: ('reiteratively',
#            {2: ('restoratively', {}), 12: ('subastragalar', {})}),
#           10: ('superthankful', {})}),
#         13: ('prestraighten', {})}),
#       8: ('cestraciontes',
#        {10: ('chrysobalanus',
#          {11: ('exuberantness',
#            {7: ('overcleanness', {8: ('pickthankness', {})}),
#             5: ('repugnantness', {})}),
#           10: ('mirthfulness',
#            {7: ('oversharpness', {}), 2: ('worthfulness', {})})}),
#         11: ('fireworkless',
#          {9: ('orbicularness',
#            {6: ('overcheapness', {}), 8: ('skillfulness', {})}),
#           8: ('prayerfulness', {})}),
#         9: ('overfrankness',
#          {5: ('oversauciness', {}),
#           9: ('physicianless', {}),
#           8: ('startlishness', {})})}),
#       6: ('cheerfulness',
#        {6: ('corporealness', {}),
#         7: ('receivablness', {7: ('spiritualness', {})}),
#         3: ('sleepfulness', {}),
#         5: ('tristfulness', {})}),
#       9: ('chrestomathic',
#        {10: ('clemclemalats',
#          {12: ('repressionary', {10: ('retrotracheal', {})})}),
#         11: ('clishmaclaver', {11: ('hemiparalysis', {})}),
#         8: ('coeliomyalgia', {}),
#         13: ('foolhardiness',
#          {7: ('gimcrackiness', {}),
#           6: ('overharshness', {}),
#           8: ('withdrawnness', {})}),
#         12: ('playwrightess', {12: ('semiparalysis', {})})}),
#       4: ('christianness', {6: ('essentialness', {})}),
#       7: ('crestfallenly',
#        {10: ('healthfulness',
#          {9: ('irregularness', {}), 6: ('powerfulness', {})}),
#         12: ('heartsickness', {}),
#         9: ('lightfulness',
#          {6: ('prelawfulness', {}),
#           1: ('rightfulness', {1: ('sightfulness', {})}),
#           4: ('shiftfulness', {})}),
#         11: ('overhastiness', {})}),
#       12: ('cryptogrammic',
#        {4: ('cryptographal', {4: ('glyptographic', {})}),
#         2: ('cryptographic', {}),
#         10: ('cyathophyllum',
#          {11: ('elytrorrhaphy', {4: ('hepatorrhaphy', {})}),
#           12: ('episiorrhagia',
#            {12: ('hypercritical', {11: ('liebfraumilch', {})}),
#             11: ('lexigraphical', {11: ('sulfocarbolic', {})}),
#             10: ('microgranular',
#              {10: ('poligraphical', {}), 12: ('pseudoaquatic', {})}),
#             9: ('musicofanatic',
#              {8: ('perilymphatic', {}),
#               11: ('postpyramidal', {}),
#               10: ('precorruptly', {})})}),
#           9: ('fractocumulus', {}),
#           4: ('hypsophyllum', {}),
#           10: ('ophthalmalgic', {}),
#           13: ('polyenzymatic',
#            {11: ('trisplanchnic', {}), 13: ('unparagraphed', {})})}),
#         13: ('diffractively',
#          {9: ('dissolutional',
#            {12: ('infrascapular', {5: ('intravalvular', {})}),
#             11: ('overanxiously', {})}),
#           8: ('efficaciously', {10: ('imperceivably', {})}),
#           10: ('extracellular',
#            {6: ('intrafistular', {}),
#             4: ('microcellular', {}),
#             10: ('overbashfully', {}),
#             11: ('overbrightly', {6: ('overfruitful', {})}),
#             12: ('overslavishly', {})}),
#           12: ('horselaughter',
#            {11: ('postpupillary',
#              {10: ('somnambulancy', {}), 12: ('uninvalidated', {})})}),
#           11: ('intercondylar',
#            {11: ('miscalculator',
#              {12: ('pericarpoidal', {}), 11: ('supersympathy', {})}),
#             10: ('periauricular', {}),
#             9: ('pluricellular', {})}),
#           13: ('periglandular', {3: ('polyglandular', {})})}),
#         11: ('diploplacular',
#          {10: ('edriophthalma',
#            {11: ('hyperdactylia',
#              {10: ('polypharmacal', {10: ('unimportantly', {})}),
#               5: ('pterodactylic', {}),
#               13: ('trisyllabical', {}),
#               9: ('typhloempyema', {})}),
#             7: ('myriophyllum', {})}),
#           13: ('extrasyllabic', {8: ('petrarchistic', {})}),
#           12: ('heptahydrated',
#            {13: ('irrefrangibly', {}),
#             10: ('nephrorrhaphy', {}),
#             11: ('perichoroidal', {8: ('spherocrystal', {})}),
#             12: ('treacherously', {})}),
#           8: ('hypsophyllary', {}),
#           11: ('inaccordantly',
#            {12: ('ophthalmalgia',
#              {9: ('oropharyngeal', {}),
#               11: ('overappraisal', {}),
#               13: ('supercritical', {}),
#               12: ('troglodytical', {})}),
#             13: ('plurisyllabic', {9: ('prosabbatical', {})}),
#             10: ('urethroplasty', {})}),
#           9: ('reproachfully', {})}),
#         12: ('dyophysitical',
#          {12: ('ectrodactylia',
#            {10: ('extraordinary', {}),
#             12: ('irreclaimably',
#              {10: ('prefabricator', {}), 2: ('unreclaimably', {})}),
#             11: ('liparomphalus',
#              {11: ('overjoyfully', {5: ('overpopularly', {})}),
#               12: ('tetrahydrated', {})}),
#             4: ('pterodactylid', {}),
#             13: ('supercolumnar', {12: ('uninvaginated', {})})}),
#           11: ('engraphically',
#            {9: ('forthrightly', {10: ('sporophyllary', {})}),
#             11: ('ophthalaiater',
#              {9: ('opticociliary', {}),
#               11: ('postlachrymal', {12: ('shipwrightry', {})})}),
#             10: ('suprascapular', {}),
#             12: ('urethrobulbar', {})}),
#           10: ('humerocubital',
#            {11: ('methylglyoxal', {13: ('unspiritually', {})}),
#             12: ('nostalgically', {}),
#             9: ('overyouthful', {}),
#             7: ('phenobarbital', {}),
#             10: ('provocatively', {})}),
#           9: ('humerodigital',
#            {7: ('hyperboloidal', {}),
#             9: ('metallurgical',
#              {11: ('supraoptional', {2: ('suprarational', {})})})}),
#           8: ('metapsychical',
#            {10: ('otopharyngeal', {}),
#             4: ('polypsychical', {}),
#             8: ('semijuridical', {}),
#             9: ('zygapophyseal', {})}),
#           13: ('overappareled',
#            {10: ('tetrasymmetry', {10: ('trilamellated', {})})})}),
#         9: ('elytrorrhagia',
#          {11: ('megaloblastic',
#            {10: ('sterhydraulic', {10: ('stratochamber', {})})}),
#           8: ('opisthophagic', {}),
#           10: ('polypragmonic', {6: ('posttraumatic', {})}),
#           9: ('pseudoarchaic', {})}),
#         8: ('microgranitic',
#          {7: ('philodramatic', {}),
#           8: ('polygrammatic', {}),
#           9: ('polypragmatic',
#            {9: ('proteoclastic', {}), 10: ('pseudographia', {})}),
#           6: ('sociodramatic', {})}),
#         7: ('photodramatic',
#          {6: ('proctoplastic', {}), 8: ('stethographic', {})}),
#         6: ('protodramatic', {})}),
#       13: ('dikaryophasic',
#        {2: ('dikaryophytic', {}),
#         9: ('diphthongally',
#          {11: ('lymphoblastic',
#            {5: ('lymphorrhagic', {}),
#             9: ('microclimatic',
#              {9: ('psychorrhagic', {}), 10: ('stratographic', {})}),
#             4: ('triploblastic', {}),
#             3: ('trophoblastic', {})}),
#           10: ('psychoorganic', {})}),
#         8: ('embryographic',
#          {11: ('ichthyophagan', {}),
#           8: ('morphoplasmic', {}),
#           9: ('trophoplasmic', {})}),
#         11: ('epitrochoidal',
#          {8: ('extrazodiacal', {}),
#           9: ('microcolumnar',
#            {11: ('preparoxysmal', {}), 10: ('ultrazodiacal', {})}),
#           10: ('microdactylia', {}),
#           11: ('myocardiogram',
#            {10: ('orthocarbonic', {}), 11: ('psychorhythm', {})})}),
#         10: ('glyphographic',
#          {11: ('hysterophytal', {11: ('schizophragma', {})}),
#           9: ('lochiorrhagia', {}),
#           7: ('lymphorrhagia', {}),
#           8: ('psychodynamic',
#            {12: ('skiagraphical', {}), 4: ('trophodynamic', {})}),
#           3: ('psychographic', {}),
#           13: ('unvicariously', {9: ('unwarrantably', {})})}),
#         12: ('ischiofibular',
#          {8: ('postauricular', {}),
#           12: ('stuffgownsman', {13: ('uninhabitably', {})}),
#           10: ('supracondylar', {}),
#           11: ('ultracritical', {})}),
#         13: ('subclavicular', {})}),
#       5: ('effectualness', {6: ('impartialness', {})})})}),
#   5: ('bronchoscope', {5: ('chromatoscope', {}), 6: ('ebullioscope', {})})})

# %%
t.tree[1][23]
# Out:
# ('epididymodeferentectomy',
#  {21: ('formaldehydesulphoxylate', {}),
#   23: ('pathologicopsychological', {}),
#   22: ('scientificophilosophical', {}),
#   20: ('tetraiodophenolphthalein', {}),
#   19: ('thyroparathyroidectomize', {})})

# %%
branches_from_root = t.tree[1]
branch_22          = branches_from_root[22]
branch_23          = branches_from_root[23]

# %%
branch_22
# Out:
# ('anthropomorphologically',
#  {20: ('blepharosphincterectomy',
#    {17: ('cholecystoduodenostomy', {13: ('duodenocholecystostomy', {})})}),
#   19: ('choledochoduodenostomy',
#    {18: ('gastroenteroanastomosis', {18: ('pseudomonocotyledonous', {})}),
#     22: ('macracanthrorhynchiasis', {}),
#     9: ('pancreaticoduodenostomy', {}),
#     19: ('phenolsulphonephthalein', {}),
#     16: ('pyopneumocholecystitis', {})}),
#   21: ('electrotelethermometer',
#    {21: ('formaldehydesulphoxylic', {20: ('transubstantiationalist', {})}),
#     20: ('hyperconscientiousness', {20: ('pseudolamellibranchiata', {})}),
#     18: ('pericardiomediastinitis', {}),
#     19: ('pseudolamellibranchiate', {})}),
#   18: ('hematospectrophotometer',
#    {22: ('scientificogeographical', {}), 19: ('thymolsulphonephthalein', {})}),
#   13: ('pathologicohistological', {}),
#   14: ('philosophicotheological', {}),
#   17: ('scleroticochorioiditis', {})})

# %%
branch_23
# Out:
# ('epididymodeferentectomy',
#  {21: ('formaldehydesulphoxylate', {}),
#   23: ('pathologicopsychological', {}),
#   22: ('scientificophilosophical', {}),
#   20: ('tetraiodophenolphthalein', {}),
#   19: ('thyroparathyroidectomize', {})})

# %% [markdown]
# ## Searching in a BK tree
#
# Now in order to search all words that appear at distance less or equal than a tolerance T form a query word `q` we need to visit all nodes n that are at distance D(n,q)+-N.
#
# Let us consider word q=caqe, T=1, candidates = [], search=[book]
#
# Select candidate **book** from search=[book]
# - edit_dist(book,caqe) = 4 => candidates is not updated
#     - Crawl all children of book at distance I=[4-1,4+1]=[3,5]
#     - There is a single node, search=[book,cake], inside I.
#     - search = [book,cake]\book = [cake]
#
# Select candidate **cake** from search=[cake]
# - edit_dist(cake,caqe) = 1 => candidates =[cake]
#     - Crawl all children of book at distance I=[1-1,1+1]=[0,2]
#     - There are 2 possible nodes, search=[cape, cart]
#
#
# Select candidate **cape** from search=[cape,cart]
# - edit_dist(cape,caqe) = 1 => candidates =[cake, cape]
#     - Crawl all children of cape at distance I=[1-1,1+1]=[0,2]
#     - Cape has no children
#     - search = [cape, cart]\cape = [cart]
#
#
# Select candidate **cart** from search=[cart]
# - edit_dist(cart,caqe) = 2 => candidates is not updated
#     - Crawl all children of cape at distance I=[1-1,1+1]=[0,2]
#     - Caqe has no children
#     - search = [cart]\cart = []
#
#
# Select candidate... There is no candidate! stop process.
#
# The resulting set of possible candidates at distance 1 are: [cape,cake].
#
# Notice that we ended up computing 4 edit distances yet we have 8 nodes.

# %% [markdown]
# ### Making queries

# %%
visited_nodes = []
class BKTree:
    def __init__(self, distfn, words):
        self.distfn = distfn

        it = iter(words)
        root = next(it)
        self.tree = (root, {})

        for i in it:
            self._add_word(self.tree, i)

    def _add_word(self, parent, word):
        pword, children = parent
        d = self.distfn(word, pword)
        # TODO BEGIN ------------------------------------------

            
        # TODO END --------------------------------------------
        
    def _search_descendants(self, parent, n, distance, query_word):
        
        node_word, children_dict = parent
        dist_to_node = distance(query_word, node_word)
        visited_nodes.append(node_word)
        results = []
        if dist_to_node <= n:
            results.append((dist_to_node, node_word))
        
        # TODO BEGIN ------------------------------------------
        # (dist - T, dist+T+1)
                    
        
        
        # TODO END --------------------------------------------

          
        return results
            
    def query(self, query_word, n):
        # sort by distance
        return sorted(self._search_descendants(self.tree, n, self.distfn, query_word))

# %%
# %%time
t = BKTree(edit_distance,words)
# Out:
# CPU times: user 2.9 s, sys: 169 ms, total: 3.07 s
# Wall time: 3.08 s

# %%
# %%time
visited_nodes = []
print(t.query("senzorial", 2))
# Out:
# [(1, 'sensorial'), (2, 'censorial'), (2, 'mentorial'), (2, 'sectorial'), (2, 'senatorial'), (2, 'sensoria'), (2, 'tentorial')]
# CPU times: user 102 ms, sys: 7.35 ms, total: 110 ms
# Wall time: 109 ms

# %%
len(visited_nodes), len(words)
# Out:
# (48613, 236736)

# %% [markdown]
# If the edit distance is slow, the construction and search in the bktree will be slow.
#
# Compare it with the nltk.edit_distance

# %%
# %%time
t_nltk = BKTree(nltk.distance.edit_distance, words)
# Out:
# CPU times: user 2min 15s, sys: 8.48 s, total: 2min 24s
# Wall time: 2min 24s

# %%
# %%time
t_nltk.query("senzorial", 2)
# Out:
# CPU times: user 3.31 s, sys: 248 ms, total: 3.56 s
# Wall time: 3.55 s
# [(1, 'sensorial'),
#  (2, 'censorial'),
#  (2, 'mentorial'),
#  (2, 'sectorial'),
#  (2, 'senatorial'),
#  (2, 'sensoria'),
#  (2, 'tentorial')]

# %%
# %%time
t.query("senzorial", 2)
# Out:
# CPU times: user 101 ms, sys: 7.86 ms, total: 109 ms
# Wall time: 108 ms
# [(1, 'sensorial'),
#  (2, 'censorial'),
#  (2, 'mentorial'),
#  (2, 'sectorial'),
#  (2, 'senatorial'),
#  (2, 'sensoria'),
#  (2, 'tentorial')]

# %% [markdown]
# ### Comparing exhaustive computation vs bktree with the same edit distance function

# %%
from typing import List

def get_candidates_exhaustive(query:str , max_dist: int, vocabulary: List[str], sort_candidates=True):
    """
    Compute the candidate words from the vocabulary at most `max_dist` away from the input token.
    Then it filters candidates by the computed values in the distance function.
    This function is mainly used for benchmarking purposes.
    :return: list of candidate words.
    """
    query = query.lower()
    distance_token_to_words = {
        word: edit_distance(query, word) for word in vocabulary
    }
    min_dist = min(distance_token_to_words.values())
    if min_dist <= max_dist:
        if sort_candidates:
            result = sorted(
                [
                    (distance, word)
                    for word, distance in distance_token_to_words.items()
                    if distance <= max_dist
                ]
            )
        else:
            result = [
                word
                for word, distance in distance_token_to_words.items()
                if distance <= max_dist
            ]
        return result

# %%
word = "anthropomorphologicaly"
max_dist = 2
sort_candidates=False
        
# %timeit candidates_ext = get_candidates_exhaustive(word,max_dist,words)
# Out:
# 404 ms ± 5.26 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
candidates_ext = get_candidates_exhaustive(word,max_dist,words)
candidates_ext
# Out:
# [(1, 'anthropomorphological'), (1, 'anthropomorphologically')]

# %%
word = "anthropomorphologicaly"

# %timeit candidates_ext = t.query(word, 2)
# Out:
# 214 µs ± 1.77 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
candidates_ext = t.query(word, 2)
candidates_ext
# Out:
# [(1, 'anthropomorphological'), (1, 'anthropomorphologically')]

# %%
word = "astrologi"
max_dist = 2
sort_candidates=False
        
# %timeit candidates_ext = get_candidates_exhaustive(word, max_dist, words)
# Out:
# 319 ms ± 1.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
word = "astrologi"

# %timeit t.query(word, 2)
# Out:
# 96.2 ms ± 737 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# Notice that we have an issue with "hamer" since it is (in edit distance) as close as "hammer"  than "haler".
#
# We would like to, somehow, choose wisely among a set of candidates.

# %%
candidates_bktree = t.query("hamer", 1)
candidates_bktree
# Out:
# [(1, 'haler'),
#  (1, 'hame'),
#  (1, 'hamel'),
#  (1, 'hammer'),
#  (1, 'hammer'),
#  (1, 'hamper'),
#  (1, 'harmer'),
#  (1, 'hater'),
#  (1, 'haver'),
#  (1, 'hawer'),
#  (1, 'hazer'),
#  (1, 'homer'),
#  (1, 'namer'),
#  (1, 'shamer'),
#  (1, 'tamer')]

# %%
# %timeit  get_candidates_exhaustive(word, max_dist, words, sort_candidates)
# %timeit  t.query(word, 1)
# Out:
# 282 ms ± 2.65 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 5.86 ms ± 28.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ## Full comparison

# %%
# %timeit  get_candidates_exhaustive(word, max_dist, words, sort_candidates)
# %timeit  t.query(word, 1)

# %% [markdown]
# ### Correcting a pharse
#
# Notice that there are several words at the same distance. Picking the correct word is not the aim for today's class. The aim is to find a small list that contains the correct word.

# %%
phrase = "the man wentt to the antimonarchik protest because he did not like the king"

# %%
# %%timeit
correction = []
for w in phrase.split(" "):
    if w in words:
        correction.append(w)
    else:
        w_similar = get_candidates_exhaustive(w, 2, words, True)
        if len(w_similar)>0:
            w_corrected = w_similar[0][1]
            correction.append(w_corrected)
        else:
            # no word found, simply append the unedited word
            correction.append(w)
# Out:
# 679 ms ± 3.16 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
print("Original:\n",phrase)
print("Corrected:\n"," ".join(correction))
# Out:
# Original:
#  the man wentt to the antimonarchik protest because he did not like the king
# Corrected:
#  the man went to the antimonarchic protest because he did not like the king

# %%
# %%timeit
correction = []
for w in phrase.split(" "):
    if w in words:
        correction.append(w)
    else:
        w_similar = t.query(w,2)
        if len(w_similar)>0:
            w_corrected = w_similar[0][1]
            correction.append(w_corrected)
        else:
            # no word found, simply append the unedited word
            correction.append(w)
# Out:
# 117 ms ± 926 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
print("Original:\n",phrase)
print("Corrected:\n"," ".join(correction))
# Out:
# Original:
#  the man wentt to the antimonarchik protest because he did not like the king
# Corrected:
#  the man went to the antimonarchic protest because he did not like the king
